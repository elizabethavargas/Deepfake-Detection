# %% [markdown]
# # Detecting Deepfakes with DINOv2

# %% [markdown]
# ## Load & Transform Dataset

# %%
# !pip install datasets

import os, zipfile, subprocess, glob, shutil
from huggingface_hub import snapshot_download
from datasets import load_dataset
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.36.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2025.11.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
# load dataset from huggingface, due to unusual file storage, it needs to be loaded manually
repo = snapshot_download("pujanpaudel/deepfake_face_classification", repo_type="dataset")
out = os.path.join(repo, "extracted")
os.makedirs(out, exist_ok=True)

def extract(src, dst):
    os.makedirs(dst, exist_ok=True)
    if src.endswith(".zip"):
        with zipfile.ZipFile(src) as z: z.extractall(dst)
    elif src.endswith(".rar"):
        if not shutil.which("unrar"):
            subprocess.run(["apt-get","update"]); subprocess.run(["apt-get","install","-y","unrar-free"])
        subprocess.run(["unrar","x","-o+",src,dst])

def find_root(p):
    imgs = glob.glob(f"{p}/**/*.[jJpP]*[gG]", recursive=True)
    class_dir = os.path.dirname(imgs[0])
    return os.path.dirname(class_dir)

splits = {"train":"train.rar","validation":"val.zip","test":"test.zip"}
datasets = {}

for split, fname in splits.items():
    path = os.path.join(repo, fname)
    if not os.path.exists(path): continue
    dst = os.path.join(out, split)
    extract(path, dst)
    root = find_root(dst)
    datasets[split] = load_dataset("imagefolder", data_dir=root)["train"]
    print(split, datasets[split])
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/25696 [00:00<?, ?it/s]
# train Dataset({
#     features: ['image', 'label'],
#     num_rows: 25696
# })
# Resolving data files:   0%|          | 0/3212 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0/3212 [00:00<?, ?files/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# validation Dataset({
#     features: ['image', 'label'],
#     num_rows: 3212
# })
# Resolving data files:   0%|          | 0/3212 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0/3212 [00:00<?, ?files/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# test Dataset({
#     features: ['image', 'label'],
#     num_rows: 3212
# })

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from torchvision import transforms

preprocess = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5]*3, std=[0.5]*3)
])

def preprocess_dataset(example):
    example["pixel_values"] = preprocess(example["image"])
    return example

train_dataset = datasets['train'].map(preprocess_dataset)
val_dataset   = datasets['validation'].map(preprocess_dataset)
#test_dataset  = datasets['test'].map(preprocess_dataset)
# Out:
# Map:   0%|          | 0/3212 [00:00<?, ? examples/s]

# %% [markdown]
# ## Finetune DINO-v2-small

# %%
from transformers import AutoModelForImageClassification
import torch

# Load the pre-trained DINOv2 model
model = AutoModelForImageClassification.from_pretrained("facebook/dinov2-small", num_labels=2)
# Out:
# Some weights of Dinov2ForImageClassification were not initialized from the model checkpoint at facebook/dinov2-small and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from transformers import Trainer, TrainingArguments

training_args = TrainingArguments(
    output_dir="./results",
    eval_strategy="epoch",
    per_device_train_batch_size=128,
    per_device_eval_batch_size=128,
    num_train_epochs=3,
    save_steps=500,
    save_total_limit=2,
    learning_rate=5e-5,
    weight_decay=0.01,
    logging_steps=50,
    dataloader_num_workers=12,
    fp16=True,
    optim="adamw_torch",


)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
)

trainer.train()
# Out:
#     <div>
#
#       <progress value='603' max='603' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [603/603 25:37, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.502800</td>
#       <td>0.296924</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.257500</td>
#       <td>0.150084</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.105000</td>
#       <td>0.090610</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=603, training_loss=0.4090970050339675, metrics={'train_runtime': 1588.8317, 'train_samples_per_second': 48.519, 'train_steps_per_second': 0.38, 'total_flos': 1.5357612203747574e+18, 'train_loss': 0.4090970050339675, 'epoch': 3.0})

# %%
from sklearn.metrics import accuracy_score

predictions = trainer.predict(val_dataset)

accuracy = accuracy_score(predictions.label_ids, predictions.predictions.argmax(-1))
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Accuracy: 0.9704

# %% [markdown]
# ### Save Model

# %%
from google.colab import drive
drive.mount('/content/drive')

import torch
torch.save(model.state_dict(), '/content/drive/MyDrive/deepfake_dino_model_full_128.pth')
print("Model saved to Google Drive.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Model saved to Google Drive.

# %% [markdown]
# ## Ablation: Train head only (vs whole model above)

# %%
from transformers import AutoModelForImageClassification
import torch

# Load the pre-trained DINOv2 model
model = AutoModelForImageClassification.from_pretrained("facebook/dinov2-small", num_labels=2)
# Out:
# Some weights of Dinov2ForImageClassification were not initialized from the model checkpoint at facebook/dinov2-small and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# only fine-tune the last layer
for param in model.parameters():
    param.requires_grad = False
for param in model.classifier.parameters():
    param.requires_grad = True

for name, param in model.named_parameters():
    print(name, param.requires_grad)
# Out:
# dinov2.embeddings.cls_token False
# dinov2.embeddings.mask_token False
# dinov2.embeddings.position_embeddings False
# dinov2.embeddings.patch_embeddings.projection.weight False
# dinov2.embeddings.patch_embeddings.projection.bias False
# dinov2.encoder.layer.0.norm1.weight False
# dinov2.encoder.layer.0.norm1.bias False
# dinov2.encoder.layer.0.attention.attention.query.weight False
# dinov2.encoder.layer.0.attention.attention.query.bias False
# dinov2.encoder.layer.0.attention.attention.key.weight False
# dinov2.encoder.layer.0.attention.attention.key.bias False
# dinov2.encoder.layer.0.attention.attention.value.weight False
# dinov2.encoder.layer.0.attention.attention.value.bias False
# dinov2.encoder.layer.0.attention.output.dense.weight False
# dinov2.encoder.layer.0.attention.output.dense.bias False
# dinov2.encoder.layer.0.layer_scale1.lambda1 False
# dinov2.encoder.layer.0.norm2.weight False
# dinov2.encoder.layer.0.norm2.bias False
# dinov2.encoder.layer.0.mlp.fc1.weight False
# dinov2.encoder.layer.0.mlp.fc1.bias False
# dinov2.encoder.layer.0.mlp.fc2.weight False
# dinov2.encoder.layer.0.mlp.fc2.bias False
# dinov2.encoder.layer.0.layer_scale2.lambda1 False
# dinov2.encoder.layer.1.norm1.weight False
# dinov2.encoder.layer.1.norm1.bias False
# dinov2.encoder.layer.1.attention.attention.query.weight False
# dinov2.encoder.layer.1.attention.attention.query.bias False
# dinov2.encoder.layer.1.attention.attention.key.weight False
# dinov2.encoder.layer.1.attention.attention.key.bias False
# dinov2.encoder.layer.1.attention.attention.value.weight False
# dinov2.encoder.layer.1.attention.attention.value.bias False
# dinov2.encoder.layer.1.attention.output.dense.weight False
# dinov2.encoder.layer.1.attention.output.dense.bias False
# dinov2.encoder.layer.1.layer_scale1.lambda1 False
# dinov2.encoder.layer.1.norm2.weight False
# dinov2.encoder.layer.1.norm2.bias False
# dinov2.encoder.layer.1.mlp.fc1.weight False
# dinov2.encoder.layer.1.mlp.fc1.bias False
# dinov2.encoder.layer.1.mlp.fc2.weight False
# dinov2.encoder.layer.1.mlp.fc2.bias False
# dinov2.encoder.layer.1.layer_scale2.lambda1 False
# dinov2.encoder.layer.2.norm1.weight False
# dinov2.encoder.layer.2.norm1.bias False
# dinov2.encoder.layer.2.attention.attention.query.weight False
# dinov2.encoder.layer.2.attention.attention.query.bias False
# dinov2.encoder.layer.2.attention.attention.key.weight False
# dinov2.encoder.layer.2.attention.attention.key.bias False
# dinov2.encoder.layer.2.attention.attention.value.weight False
# dinov2.encoder.layer.2.attention.attention.value.bias False
# dinov2.encoder.layer.2.attention.output.dense.weight False
# dinov2.encoder.layer.2.attention.output.dense.bias False
# dinov2.encoder.layer.2.layer_scale1.lambda1 False
# dinov2.encoder.layer.2.norm2.weight False
# dinov2.encoder.layer.2.norm2.bias False
# dinov2.encoder.layer.2.mlp.fc1.weight False
# dinov2.encoder.layer.2.mlp.fc1.bias False
# dinov2.encoder.layer.2.mlp.fc2.weight False
# dinov2.encoder.layer.2.mlp.fc2.bias False
# dinov2.encoder.layer.2.layer_scale2.lambda1 False
# dinov2.encoder.layer.3.norm1.weight False
# dinov2.encoder.layer.3.norm1.bias False
# dinov2.encoder.layer.3.attention.attention.query.weight False
# dinov2.encoder.layer.3.attention.attention.query.bias False
# dinov2.encoder.layer.3.attention.attention.key.weight False
# dinov2.encoder.layer.3.attention.attention.key.bias False
# dinov2.encoder.layer.3.attention.attention.value.weight False
# dinov2.encoder.layer.3.attention.attention.value.bias False
# dinov2.encoder.layer.3.attention.output.dense.weight False
# dinov2.encoder.layer.3.attention.output.dense.bias False
# dinov2.encoder.layer.3.layer_scale1.lambda1 False
# dinov2.encoder.layer.3.norm2.weight False
# dinov2.encoder.layer.3.norm2.bias False
# dinov2.encoder.layer.3.mlp.fc1.weight False
# dinov2.encoder.layer.3.mlp.fc1.bias False
# dinov2.encoder.layer.3.mlp.fc2.weight False
# dinov2.encoder.layer.3.mlp.fc2.bias False
# dinov2.encoder.layer.3.layer_scale2.lambda1 False
# dinov2.encoder.layer.4.norm1.weight False
# dinov2.encoder.layer.4.norm1.bias False
# dinov2.encoder.layer.4.attention.attention.query.weight False
# dinov2.encoder.layer.4.attention.attention.query.bias False
# dinov2.encoder.layer.4.attention.attention.key.weight False
# dinov2.encoder.layer.4.attention.attention.key.bias False
# dinov2.encoder.layer.4.attention.attention.value.weight False
# dinov2.encoder.layer.4.attention.attention.value.bias False
# dinov2.encoder.layer.4.attention.output.dense.weight False
# dinov2.encoder.layer.4.attention.output.dense.bias False
# dinov2.encoder.layer.4.layer_scale1.lambda1 False
# dinov2.encoder.layer.4.norm2.weight False
# dinov2.encoder.layer.4.norm2.bias False
# dinov2.encoder.layer.4.mlp.fc1.weight False
# dinov2.encoder.layer.4.mlp.fc1.bias False
# dinov2.encoder.layer.4.mlp.fc2.weight False
# dinov2.encoder.layer.4.mlp.fc2.bias False
# dinov2.encoder.layer.4.layer_scale2.lambda1 False
# dinov2.encoder.layer.5.norm1.weight False
# dinov2.encoder.layer.5.norm1.bias False
# dinov2.encoder.layer.5.attention.attention.query.weight False
# dinov2.encoder.layer.5.attention.attention.query.bias False
# dinov2.encoder.layer.5.attention.attention.key.weight False
# dinov2.encoder.layer.5.attention.attention.key.bias False
# dinov2.encoder.layer.5.attention.attention.value.weight False
# dinov2.encoder.layer.5.attention.attention.value.bias False
# dinov2.encoder.layer.5.attention.output.dense.weight False
# dinov2.encoder.layer.5.attention.output.dense.bias False
# dinov2.encoder.layer.5.layer_scale1.lambda1 False
# dinov2.encoder.layer.5.norm2.weight False
# dinov2.encoder.layer.5.norm2.bias False
# dinov2.encoder.layer.5.mlp.fc1.weight False
# dinov2.encoder.layer.5.mlp.fc1.bias False
# dinov2.encoder.layer.5.mlp.fc2.weight False
# dinov2.encoder.layer.5.mlp.fc2.bias False
# dinov2.encoder.layer.5.layer_scale2.lambda1 False
# dinov2.encoder.layer.6.norm1.weight False
# dinov2.encoder.layer.6.norm1.bias False
# dinov2.encoder.layer.6.attention.attention.query.weight False
# dinov2.encoder.layer.6.attention.attention.query.bias False
# dinov2.encoder.layer.6.attention.attention.key.weight False
# dinov2.encoder.layer.6.attention.attention.key.bias False
# dinov2.encoder.layer.6.attention.attention.value.weight False
# dinov2.encoder.layer.6.attention.attention.value.bias False
# dinov2.encoder.layer.6.attention.output.dense.weight False
# dinov2.encoder.layer.6.attention.output.dense.bias False
# dinov2.encoder.layer.6.layer_scale1.lambda1 False
# dinov2.encoder.layer.6.norm2.weight False
# dinov2.encoder.layer.6.norm2.bias False
# dinov2.encoder.layer.6.mlp.fc1.weight False
# dinov2.encoder.layer.6.mlp.fc1.bias False
# dinov2.encoder.layer.6.mlp.fc2.weight False
# dinov2.encoder.layer.6.mlp.fc2.bias False
# dinov2.encoder.layer.6.layer_scale2.lambda1 False
# dinov2.encoder.layer.7.norm1.weight False
# dinov2.encoder.layer.7.norm1.bias False
# dinov2.encoder.layer.7.attention.attention.query.weight False
# dinov2.encoder.layer.7.attention.attention.query.bias False
# dinov2.encoder.layer.7.attention.attention.key.weight False
# dinov2.encoder.layer.7.attention.attention.key.bias False
# dinov2.encoder.layer.7.attention.attention.value.weight False
# dinov2.encoder.layer.7.attention.attention.value.bias False
# dinov2.encoder.layer.7.attention.output.dense.weight False
# dinov2.encoder.layer.7.attention.output.dense.bias False
# dinov2.encoder.layer.7.layer_scale1.lambda1 False
# dinov2.encoder.layer.7.norm2.weight False
# dinov2.encoder.layer.7.norm2.bias False
# dinov2.encoder.layer.7.mlp.fc1.weight False
# dinov2.encoder.layer.7.mlp.fc1.bias False
# dinov2.encoder.layer.7.mlp.fc2.weight False
# dinov2.encoder.layer.7.mlp.fc2.bias False
# dinov2.encoder.layer.7.layer_scale2.lambda1 False
# dinov2.encoder.layer.8.norm1.weight False
# dinov2.encoder.layer.8.norm1.bias False
# dinov2.encoder.layer.8.attention.attention.query.weight False
# dinov2.encoder.layer.8.attention.attention.query.bias False
# dinov2.encoder.layer.8.attention.attention.key.weight False
# dinov2.encoder.layer.8.attention.attention.key.bias False
# dinov2.encoder.layer.8.attention.attention.value.weight False
# dinov2.encoder.layer.8.attention.attention.value.bias False
# dinov2.encoder.layer.8.attention.output.dense.weight False
# dinov2.encoder.layer.8.attention.output.dense.bias False
# dinov2.encoder.layer.8.layer_scale1.lambda1 False
# dinov2.encoder.layer.8.norm2.weight False
# dinov2.encoder.layer.8.norm2.bias False
# dinov2.encoder.layer.8.mlp.fc1.weight False
# dinov2.encoder.layer.8.mlp.fc1.bias False
# dinov2.encoder.layer.8.mlp.fc2.weight False
# dinov2.encoder.layer.8.mlp.fc2.bias False
# dinov2.encoder.layer.8.layer_scale2.lambda1 False
# dinov2.encoder.layer.9.norm1.weight False
# dinov2.encoder.layer.9.norm1.bias False
# dinov2.encoder.layer.9.attention.attention.query.weight False
# dinov2.encoder.layer.9.attention.attention.query.bias False
# dinov2.encoder.layer.9.attention.attention.key.weight False
# dinov2.encoder.layer.9.attention.attention.key.bias False
# dinov2.encoder.layer.9.attention.attention.value.weight False
# dinov2.encoder.layer.9.attention.attention.value.bias False
# dinov2.encoder.layer.9.attention.output.dense.weight False
# dinov2.encoder.layer.9.attention.output.dense.bias False
# dinov2.encoder.layer.9.layer_scale1.lambda1 False
# dinov2.encoder.layer.9.norm2.weight False
# dinov2.encoder.layer.9.norm2.bias False
# dinov2.encoder.layer.9.mlp.fc1.weight False
# dinov2.encoder.layer.9.mlp.fc1.bias False
# dinov2.encoder.layer.9.mlp.fc2.weight False
# dinov2.encoder.layer.9.mlp.fc2.bias False
# dinov2.encoder.layer.9.layer_scale2.lambda1 False
# dinov2.encoder.layer.10.norm1.weight False
# dinov2.encoder.layer.10.norm1.bias False
# dinov2.encoder.layer.10.attention.attention.query.weight False
# dinov2.encoder.layer.10.attention.attention.query.bias False
# dinov2.encoder.layer.10.attention.attention.key.weight False
# dinov2.encoder.layer.10.attention.attention.key.bias False
# dinov2.encoder.layer.10.attention.attention.value.weight False
# dinov2.encoder.layer.10.attention.attention.value.bias False
# dinov2.encoder.layer.10.attention.output.dense.weight False
# dinov2.encoder.layer.10.attention.output.dense.bias False
# dinov2.encoder.layer.10.layer_scale1.lambda1 False
# dinov2.encoder.layer.10.norm2.weight False
# dinov2.encoder.layer.10.norm2.bias False
# dinov2.encoder.layer.10.mlp.fc1.weight False
# dinov2.encoder.layer.10.mlp.fc1.bias False
# dinov2.encoder.layer.10.mlp.fc2.weight False
# dinov2.encoder.layer.10.mlp.fc2.bias False
# dinov2.encoder.layer.10.layer_scale2.lambda1 False
# dinov2.encoder.layer.11.norm1.weight False
# dinov2.encoder.layer.11.norm1.bias False
# dinov2.encoder.layer.11.attention.attention.query.weight False
# dinov2.encoder.layer.11.attention.attention.query.bias False
# dinov2.encoder.layer.11.attention.attention.key.weight False
# dinov2.encoder.layer.11.attention.attention.key.bias False
# dinov2.encoder.layer.11.attention.attention.value.weight False
# dinov2.encoder.layer.11.attention.attention.value.bias False
# dinov2.encoder.layer.11.attention.output.dense.weight False
# dinov2.encoder.layer.11.attention.output.dense.bias False
# dinov2.encoder.layer.11.layer_scale1.lambda1 False
# dinov2.encoder.layer.11.norm2.weight False
# dinov2.encoder.layer.11.norm2.bias False
# dinov2.encoder.layer.11.mlp.fc1.weight False
# dinov2.encoder.layer.11.mlp.fc1.bias False
# dinov2.encoder.layer.11.mlp.fc2.weight False
# dinov2.encoder.layer.11.mlp.fc2.bias False
# dinov2.encoder.layer.11.layer_scale2.lambda1 False
# dinov2.layernorm.weight False
# dinov2.layernorm.bias False
# classifier.weight True
# classifier.bias True

# %%
from transformers import Trainer, TrainingArguments

training_args = TrainingArguments(
    output_dir="./results",
    eval_strategy="epoch",
    per_device_train_batch_size=128,
    per_device_eval_batch_size=128,
    num_train_epochs=3,
    save_steps=500,
    save_total_limit=2,
    learning_rate=5e-5,
    weight_decay=0.01,
    logging_steps=50,
    dataloader_num_workers=12,
    fp16=True,
    optim="adamw_torch",
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
)

trainer.train()
# Out:
#     <div>
#
#       <progress value='463' max='603' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [463/603 19:06 < 05:48, 0.40 it/s, Epoch 2.30/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.472300</td>
#       <td>0.407770</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.400700</td>
#       <td>0.368274</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
from sklearn.metrics import accuracy_score

predictions = trainer.predict(val_dataset)

accuracy = accuracy_score(predictions.label_ids, predictions.predictions.argmax(-1))
print(f"Accuracy: {accuracy:.4f}")

# %% [markdown]
# ### Save Model

# %%
from google.colab import drive
drive.mount('/content/drive')

import torch
torch.save(model.state_dict(), '/content/drive/MyDrive/deepfake_dino_model_head_128.pth')
print("Model saved to Google Drive.")
